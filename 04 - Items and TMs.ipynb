# %%
# %run 'National Pokedex.ipynb'

# %%
# Maximize display of all dataframes
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Scrape Items Table from Pokemon Database

# %%
items_url = 'https://pokemondb.net/item/all'
scrape_table(items_url)
# Realign dataframe
df.columns = df.iloc[0]
df = df.iloc[1:]
df = df.rename(columns = {'Name':'Item'})

# %% [markdown]
# #### Held Items

# %%
# Simpler to scrape and apply general transformations once, then filter than to scrape each sub-url
held_items = df[df['Category'] == 'Hold items'].drop('Category', axis=1)
held_items.head()
# Out:
# 0              Item  \
# 1   Ability Capsule
# 5         Abomasite
# 6          Absolite
# 7       Absorb Bulb
# 12  Adamant Crystal
#
# 0                                                                                                  Effect
# 1   A capsule that allows a Pokémon with two Abilities to switch between these Abilities when it is used.
# 5                                                         Enables Abomasnow to Mega Evolve during battle.
# 6                                                             Enables Absol to Mega Evolve during battle.
# 7                    A consumable bulb. If the holder is hit by a Water-type move, its Sp. Atk will rise.
# 12

# %% [markdown]
# #### General Items

# %%
general_items = df[df['Category'] == 'General items'].drop('Category', axis=1)
general_items.head()
# Out:
# 0              Item  \
# 2     Ability Patch
# 21  Alomomola Mucus
# 29     Applin Juice
# 30         Apricorn
# 31     Armor Fossil
#
# 0                                                                                                              Effect
# 2                                                                  Changes a Pokémon's ability to its Hidden Ability.
# 21                                         Material obtained after defeating/catching Alomomola, used in TM crafting.
# 29                                            Material obtained after defeating/catching Applin, used in TM crafting.
# 30  A fruit whose shell can be used to form the capsules of all manner of Poké Balls when crafting them from scratch.
# 31                     A fossil from a prehistoric Pokémon that lived on the land. It appears to be part of a collar.

# %% [markdown]
# #### Berries

# %%
berries = df[df['Category'] == 'Berries'].rename(columns = {'Item':'Berry'}).drop('Category', axis=1)
berries.head()
# Out:
# 0          Berry  \
# 18   Aguav Berry
# 27  Apicot Berry
# 34  Aspear Berry
# 46  Babiri Berry
# 64   Belue Berry
#
# 0                                                                                   Effect
# 18                                       Restores HP if it's low, but may cause confusion.
# 27                                                  Raises Special Defense when HP is low.
# 34                                                   If held by a Pokémon, it defrosts it.
# 46                 Weakens a supereffective Steel-type attack against the holding Pokémon.
# 64  A Berry which is very rare in the Unova region. A maniac will buy it for a high price.

# %% [markdown]
# #### Battle Items

# %%
battle_items = df[df['Category'] == 'Battle items'].drop('Category', axis=1)
battle_items.head()
# Out:
# 0           Item  \
# 4   Ability Urge
# 13  Adamant Mint
# 38   Aux Evasion
# 39     Aux Guard
# 40     Aux Power
#
# 0                                                             Effect
# 4            When used, it activates the Ability of an ally Pokémon.
# 13          Changes the Pokémon's stats to match the Adamant nature.
# 38      Makes moves less likely to strike a Pokémon during a battle.
# 39  Sharply boosts the defensive stats of a Pokémon during a battle.
# 40  Sharply boosts the offensive stats of a Pokémon during a battle.

# %% [markdown]
# #### Medicine

# %%
medicine = df[df['Category'] == 'Medicine'].rename(columns = {'Item':'Medicine'}).drop('Category', axis=1)
medicine.head()
# Out:
# 0        Medicine                              Effect
# 26       Antidote       Cures a Pokémon of poisoning.
# 43      Awakening        Wakes up a sleeping Pokémon.
# 66    Berry Juice                     Restores 20 HP.
# 69   Big Malasada  Heals all major status conditions.
# 123     Burn Heal          Cures a Pokémon of a burn.

# %% [markdown]
# #### Pokeballs

# %%
pokeballs = df[df['Category'] == 'Pokeballs'].rename(columns = {'Item':'Pokeball'}).drop('Category', axis=1)
pokeballs.head()
# Out:
# 0        Pokeball  \
# 62     Beast Ball
# 148  Cherish Ball
# 224     Dive Ball
# 239    Dream Ball
# 247     Dusk Ball
#
# 0                                                                                                      Effect
# 62         A special Poké Ball designed to catch Ultra Beasts. It has a low success rate for catching others.
# 148                                                                     Rre Poké Ball used for event Pokémon.
# 224                            Catches Pokémon that live in water with 3.5x the rate of a standard Poké Ball.
# 239  A special Poké Ball that appears out of nowhere in a bag at the Entree Forest. It can catch any Pokémon.
# 247                            Catches Pokémon at night or in caves with 3x the rate of a standard Poké Ball.

# %% [markdown]
# #### Filter Items (more user functionality explored in 'Widgets' notebook)

# %%
held_items[held_items['Item'] == 'Choice Scarf']
# Out:
# 0            Item                                        Effect
# 158  Choice Scarf  Raises Speed, but only one move can be used.

# %%
general_items[general_items['Item'] == 'Dome Fossil']
# Out:
# 0           Item  \
# 226  Dome Fossil
#
# 0                                                                                     Effect
# 226  A fossil of an ancient Pokémon that lived in the sea. It appears to be part of a shell.

# %%
berries[berries['Berry'] == 'Pomeg Berry']
# Out:
# 0          Berry                                   Effect
# 737  Pomeg Berry  Increases Friendship but lowers HP EVs.

# %%
battle_items[battle_items['Item'] == 'X Speed']
# Out:
# 0        Item                                Effect
# 1451  X Speed  Raises Speed of a Pokémon in battle.

# %%
medicine[medicine['Medicine'] == 'Sacred Ash']
# Out:
# 0      Medicine                                                    Effect
# 860  Sacred Ash  Revives all fainted Pokémon and fully restores their HP.

# %%
pokeballs[pokeballs['Pokeball'] == 'Safari Ball']
# Out:
# 0       Pokeball                                              Effect
# 861  Safari Ball  Catches Pokémon in the Safari Zone or Great Marsh.

# %% [markdown]
# ### Scrape and Apply Transformations to TMs tables for Each Pokemon Game

# %% [markdown]
# #### FireRed/LeafGreen - Gen3

# %%
url = 'https://pokemondb.net/firered-leafgreen/tms'
scrape_table(url)
FRLG_df = df
# Apply transformations
FRLG_df.columns = FRLG_df.iloc[0]
FRLG_df = FRLG_df.iloc[1:].rename(columns = {'Cat.':'Category','Acc.':'Accuracy'})
FRLG_df = FRLG_df[['TM', 'Name', 'Type', 'Category', 'PP', 'Power', 'Accuracy', 'Location']]
FRLG_df['Category'] = FRLG_df['Category'].replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-physical.png', 'Physical')\
                                .replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-special.png', 'Special')\
                                .replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-status.png', 'Other')
FRLG_df.head()
# Out:
# 0  TM         Name      Type  Category  PP Power Accuracy  \
# 1  01  Focus Punch  Fighting  Physical  20   150      100
# 2  02  Dragon Claw    Dragon  Physical  15    80      100
# 3  03  Water Pulse     Water   Special  20    60      100
# 4  04    Calm Mind   Psychic     Other  20     —        —
# 5  05         Roar    Normal     Other  20     —        —
#
# 0                                                       Location
# 1                                      Silph Co. (5F, southwest)
# 2                                       Victory Road (1F, north)
# 3                             Cerulean City (Gym - defeat Misty)
# 4                            Saffron City (Gym - defeat Sabrina)
# 5  Route 4 (northeast)\nCeladon City (Department Store - $1,000)

# %%
# Query TM
FRLG_df[FRLG_df['Name'] == 'Earthquake']
# Out:
# 0   TM        Name    Type  Category  PP Power Accuracy  \
# 26  26  Earthquake  Ground  Physical  10   100      100
#
# 0                                Location
# 26  Viridian City (Gym - defeat Giovanni)

# %% [markdown]
# #### Ruby/Sapphire/Emerald - Gen3

# %%
url = 'https://pokemondb.net/ruby-sapphire/tms'
scrape_table(url)
RSE_df = df
# Apply transformations
RSE_df.columns = RSE_df.iloc[0]
RSE_df = RSE_df.iloc[1:].rename(columns = {'Cat.':'Category','Acc.':'Accuracy'})
RSE_df = RSE_df[['TM', 'Name', 'Type', 'Category', 'PP', 'Power', 'Accuracy', 'Location']]
RSE_df['Category'] = RSE_df['Category'].replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-physical.png', 'Physical')\
                                .replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-special.png', 'Special')\
                                .replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-status.png', 'Other')
RSE_df.head()
# Out:
# 0  TM         Name      Type  Category  PP Power Accuracy  \
# 1  01  Focus Punch  Fighting  Physical  20   150      100
# 2  02  Dragon Claw    Dragon  Physical  15    80      100
# 3  03  Water Pulse     Water   Special  20    60      100
# 4  04    Calm Mind   Psychic     Other  20     —        —
# 5  05         Roar    Normal     Other  20     —        —
#
# 0                                                                   Location
# 1  Route 115 (south)\n (Pickup ability in Emerald, 1% chance at level 71-90)
# 2                                                               Meteor Falls
# 3                                Sootopolis City (Gym - defeat Wallace/Juan)
# 4                                   Mossdeep City (Gym - defeat Tate & Liza)
# 5                                                                  Route 114

# %%
# Query TM
RSE_df[RSE_df['Name'] == 'Calm Mind']
# Out:
# 0  TM       Name     Type Category  PP Power Accuracy  \
# 4  04  Calm Mind  Psychic    Other  20     —        —
#
# 0                                  Location
# 4  Mossdeep City (Gym - defeat Tate & Liza)

# %% [markdown]
# #### Diamond/Pearl/Platinum - Gen4

# %%
url = 'https://pokemondb.net/diamond-pearl/tms'
scrape_table(url)
DPP_df = df
# Apply transformations
DPP_df.columns = DPP_df.iloc[0]
DPP_df = DPP_df.iloc[1:].rename(columns = {'Cat.':'Category','Acc.':'Accuracy'})
DPP_df = DPP_df[['TM', 'Name', 'Type', 'Category', 'PP', 'Power', 'Accuracy', 'Location']]
DPP_df['Category'] = DPP_df['Category'].replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-physical.png', 'Physical')\
                                .replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-special.png', 'Special')\
                                .replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-status.png', 'Other')
DPP_df.head()
# Out:
# 0  TM         Name      Type  Category  PP Power Accuracy  \
# 1  01  Focus Punch  Fighting  Physical  20   150      100
# 2  02  Dragon Claw    Dragon  Physical  15    80      100
# 3  03  Water Pulse     Water   Special  20    60      100
# 4  04    Calm Mind   Psychic     Other  20     —        —
# 5  05         Roar    Normal     Other  20     —        —
#
# 0                                                                Location
# 1  Oreburgh Gate (B1F, west)\n (Pickup ability, 1% chance at level 71-90)
# 2                      Mt. Coronet (uppermost cave - requires Rock Climb)
# 3                 Ravaged Path (northeast - requires Surf and Rock Smash)
# 4                                                     Battle Park (48 BP)
# 5                             Route 213 (northwest - requires Rock Climb)

# %%
# Query TM
DPP_df[DPP_df['Name'] == 'Overheat']
# Out:
# 0   TM      Name  Type Category PP Power Accuracy  \
# 50  50  Overheat  Fire  Special  5   130       90
#
# 0                               Location
# 50  Stark Mountain (Interior, southwest)

# %% [markdown]
# #### HeartGold/SoulSilver - Gen4

# %%
url = 'https://pokemondb.net/heartgold-soulsilver/tms'
scrape_table(url)
HGSS_df = df
# Apply transformations
HGSS_df.columns = HGSS_df.iloc[0]
HGSS_df = HGSS_df.iloc[1:].rename(columns = {'Cat.':'Category','Acc.':'Accuracy'})
HGSS_df = HGSS_df[['TM', 'Name', 'Type', 'Category', 'PP', 'Power', 'Accuracy', 'Location']]
HGSS_df['Category'] = HGSS_df['Category'].replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-physical.png', 'Physical')\
                                .replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-special.png', 'Special')\
                                .replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-status.png', 'Other')
HGSS_df.head()
# Out:
# 0  TM         Name      Type  Category  PP Power Accuracy  \
# 1  01  Focus Punch  Fighting  Physical  20   150      100
# 2  02  Dragon Claw    Dragon  Physical  15    80      100
# 3  03  Water Pulse     Water   Special  20    60      100
# 4  04    Calm Mind   Psychic     Other  20     —        —
# 5  05         Roar    Normal     Other  20     —        —
#
# 0                                     Location
# 1           Cianwood City (Gym - defeat Chuck)
# 2  Route 27\nGoldenrod City (Lottery - Sunday)
# 3           Cerulean City (Gym - defeat Misty)
# 4                      Battle Frontier (48 BP)
# 5                                     Route 32

# %%
# Query TM
HGSS_df[HGSS_df['Name'] == 'Dragon Pulse']
# Out:
# 0   TM          Name    Type Category  PP Power Accuracy  \
# 59  59  Dragon Pulse  Dragon  Special  10    85      100
#
# 0                                                        Location
# 59  Blackthorn City (Gym - defeat Clair)\nBattle Frontier (80 BP)

# %% [markdown]
# #### Black/White - Gen5

# %%
url = 'https://pokemondb.net/black-white/tms'
scrape_table(url)
BW_df = df
# Apply transformations
BW_df.columns = BW_df.iloc[0]
BW_df = BW_df.iloc[1:].rename(columns = {'Cat.':'Category','Acc.':'Accuracy'})
BW_df = BW_df[['TM', 'Name', 'Type', 'Category', 'PP', 'Power', 'Accuracy', 'Location']]
BW_df['Category'] = BW_df['Category'].replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-physical.png', 'Physical')\
                                .replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-special.png', 'Special')\
                                .replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-status.png', 'Other')
BW_df.head()
# Out:
# 0  TM         Name     Type  Category  PP Power Accuracy  \
# 1  01   Hone Claws     Dark     Other  15     —        —
# 2  02  Dragon Claw   Dragon  Physical  15    80      100
# 3  03     Psyshock  Psychic   Special  10    80      100
# 4  04    Calm Mind  Psychic     Other  20     —        —
# 5  05         Roar   Normal     Other  20     —        —
#
# 0                       Location
# 1  Cold Storage (Gift from Sage)
# 2              Victory Road (3F)
# 3                    Giant Chasm
# 4  Relic Castle (Gift from Sage)
# 5                       Route 10

# %%
# Query TM
BW_df[BW_df['Name'] == 'Sky Drop']
# Out:
# 0   TM      Name    Type  Category  PP Power Accuracy         Location
# 58  58  Sky Drop  Flying  Physical  10    60      100  Mistralton City

# %% [markdown]
# #### Black2/White2 - Gen5

# %%
url = 'https://pokemondb.net/black-white-2/tms'
scrape_table(url)
BW2_df = df
# Apply transformations
BW2_df.columns = BW2_df.iloc[0]
BW2_df = BW2_df.iloc[1:].rename(columns = {'Cat.':'Category','Acc.':'Accuracy'})
BW2_df = BW2_df[['TM', 'Name', 'Type', 'Category', 'PP', 'Power', 'Accuracy', 'Location']]
BW2_df['Category'] = BW2_df['Category'].replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-physical.png', 'Physical')\
                                .replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-special.png', 'Special')\
                                .replace('https://www.serebii.nethttps://img.pokemondb.net/images/icons/move-status.png', 'Other')
BW2_df.head()
# Out:
# 0  TM         Name     Type  Category  PP Power Accuracy  \
# 1  01   Hone Claws     Dark     Other  15     —        —
# 2  02  Dragon Claw   Dragon  Physical  15    80      100
# 3  03     Psyshock  Psychic   Special  10    80      100
# 4  04    Calm Mind  Psychic     Other  20     —        —
# 5  05         Roar   Normal     Other  20     —        —
#
# 0                            Location
# 1  Victory Road (Entrance area, east)
# 2             Dragonspiral Tower (5F)
# 3          Giant Chasm (Plains, west)
# 4  Striaton City (PokeMart - $80,000)
# 5            Route 23 (2F, southwest)

# %%
# Query TM
BW2_df[BW2_df['Name'] == 'Dragon Tail']
# Out:
# 0   TM         Name    Type  Category  PP Power Accuracy  \
# 82  82  Dragon Tail  Dragon  Physical  10    60       90
#
# 0                               Location
# 82  Opelucid City (Gym - defeat Drayden)
